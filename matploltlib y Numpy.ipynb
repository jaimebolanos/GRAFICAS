# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">Gráficas por defecto </p>

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)

plt.show()

# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">Cambiando colores y anchos de linea</p>

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)

plt.figure(figsize=(10,6), dpi=80) # dots per inch
plt.plot(X, C, color="green", linewidth=2.5, linestyle="-.")
#  ver colors in matplotlib

plt.plot(X, S, color="olive",  linewidth=2.5, linestyle=":")
plt.show()

# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">Cambiando Límites</p>

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)

plt.xlim(X.min()*1.5, X.max()*1.5)
plt.ylim(C.min()*0.5, C.max()*2.5)
plt.show()

# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">Cambiando Ticks </p>
# <p style="text-align: left;font-family:Arial;font-size:32px;Color:b ">Utilizando  $\pi$ en la escala horizontal</p>

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)
##########################################
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
       [r'$-1$', r'$0$', r'$+1$'])
############################################
plt.show()

# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">Moving Spines </p>
# <p style="text-align: left;font-family:Arial;font-size:32px;Color:b ">Ejes coordenados?l</p>

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)
##########################################
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
       [r'$-1$', r'$0$', r'$+1$'])
############################################






ax = plt.gca()
ax.spines['right'].set_color('r')
ax.spines['top'].set_color('g')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.show()

# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">Uso de los Subplots </p>
# <p style="text-align: left;font-family:Arial;font-size:32px;Color:b ">Dos Areas de Gráfico en una misma ventana(figure)</p>

# %%
plt.ion()# Nos ponemos en  modo interactivo
plt.subplot(1,2,1) # Dividimos la ventana en una fila y dos columnas y dibujamos el primer grafico
plt.plot((1,2,3,4,5,6))
plt.subplot(1,2,2) # Dividimos la ventana en una fila y dos columnas y dibujamos el segundo gráfico
plt.plot((6,5,4,3,2,1))

# %%
plt.ion()# Nos ponemos en  modo interactivo

plt.subplot(2,2,1) # Dividimos la ventana en una fila y dos columnas y dibujamos el primer grafico
plt.plot((1,2,2,4,5,1))

plt.subplot(2,2,2) # Dividimos la ventana en una fila y dos columnas y dibujamos el segundo gráfico
plt.plot((5,2,2,4,5,5))

plt.subplot(2,2,3) 
plt.plot((2,1,2,4,5,1))

plt.subplot(2,2,4) 
plt.plot((5,2,2,4,5,5))

# %%
plt.ion()# Nos ponemos en  modo interactivo
plt.subplot(2,1,1) # Dividimos la ventana en una fila y dos columnas y dibujamos el primer grafico
plt.plot((1,2,3,4,5,6))
plt.subplot(2,1,2) # Dividimos la ventana en una fila y dos columnas y dibujamos el segundo gráfico
plt.plot((6,5,4,3,2,1))

# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">Axes </p>

# %%
ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.4, 0.60, 0.2, 0.25])

# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">Uso de fig.add_axes().</p>
#  <p style="text-align: left;font-family:Arial;font-size:32px;Color:b ">Arreglos verticales</p>

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));

# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">Otro aspectos</p>

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.axes([0.025,0.025,0.95,0.95])

ax.set_xlim(0,4)
ax.set_ylim(0,3)
ax.xaxis.set_major_locator(plt.MultipleLocator(1.0))
ax.xaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax.yaxis.set_major_locator(plt.MultipleLocator(1.0))
ax.yaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax.grid(which='major', axis='x', linewidth=0.75, linestyle='-', color='0.1')
ax.grid(which='minor', axis='x', linewidth=0.25, linestyle='-', color='0.75')
ax.grid(which='major', axis='y', linewidth=0.75, linestyle='-', color='0.75')
ax.grid(which='minor', axis='y', linewidth=0.25, linestyle='-', color='0.75')
ax.set_xticklabels([])
ax.set_yticklabels([])

# savefig('../figures/grid_ex.png',dpi=48)
plt.show()

# %% [markdown]
# <p style="text-align: center;font-family:Arial;font-size:32px;Color:red ">AGREGANDO LEYENDAS, TEXTO Y FLECHAS</p>

# %%
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-", label="sine")

plt.legend(loc='upper left', frameon=False)
t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)], color ='blue', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.cos(t),], 50, color ='blue')

plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t,t],[0,np.sin(t)], color ='red', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.sin(t),], 50, color ='red')

plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
# Out:
# Text(-90,-50,u'$\\cos(\\frac{2\\pi}{3})=-\\frac{1}{2}$')
