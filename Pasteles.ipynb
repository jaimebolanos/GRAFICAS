# %%
import matplotlib.pyplot as plt
plt.figure()
values = [3, 12, 5, 8] 
labels = ['a', 'b', 'c', 'd'] 
plt.pie(values, labels=labels) #autopct??
plt.title('Este es mi primer pastel')
plt.show()

# %%
plt.figure()
valores = [10, 22, 35, 40] 
letras = ['a', 'b', 'c', 'd'] 
explode = (0, 0.2, 0, 0) 
plt.pie(valores, 
        labels=letras, 
        explode=explode, 
        autopct='%1.1f%%',
        shadow=True,
        startangle=90 
       )
plt.title('Este es mi segundo pastel pastel')
plt.show()

# %% [markdown]
# # Con Orientacion al objeto

# %%
plt.figure()
valores = [10, 22, 35, 40] 
letras = ['a', 'b', 'c', 'd'] 
explode = (0, 0.2, 0, 0) 
fig1, ax1 = plt.subplots()

ax1.pie(valores, 
        labels=letras, 
        explode=explode, 
        autopct='%1.1f%%',
        shadow=True,
        startangle=90 
       )
plt.title('Este es mi tercer pastel')
plt.show()

# %%
import matplotlib.pyplot as plt
 
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.2f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()
